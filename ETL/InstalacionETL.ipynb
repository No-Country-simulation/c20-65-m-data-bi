# %%
#Carga de librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Intenta con 'latin-1'
df = pd.read_csv('dfr_facility_socrata_fy2024.csv', encoding='latin-1')
# Out:
# C:\Users\miass\AppData\Local\Temp\ipykernel_11908\164428657.py:2: DtypeWarning: Columns (6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('dfr_facility_socrata_fy2024.csv', encoding='latin-1')

# %%
df.head(10)
# Out:
#   state    CCN                       Provider_Name        city Ownership_Type  \
# 0    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 1    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 2    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 3    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 4    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 5    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 6    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 7    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 8    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
# 9    AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM    Unavailable
#
#    ESRD_Network         NPI        Chain  \
# 0             8  1720166085  INDEPENDENT
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11679242 entries, 0 to 11679241
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   state           object
#  1   CCN             int64
#  2   Provider_Name   object
#  3   city            object
#  4   Ownership_Type  object
#  5   ESRD_Network    int64
#  6   NPI             object
#  7   Chain           object
#  8   Modality        object
#  9   Alternate_CCNs  object
#  10  Measure         object
#  11  Measure_Score   float64
#  12  year            object
#  13  Measure_ID      object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.2+ GB

# %%
df.describe()
# Out:
#                 CCN  ESRD_Network  Measure_Score
# count  1.167924e+07  1.167924e+07   1.167924e+07
# mean   3.186338e+05  9.672869e+00   7.035662e+01
# std    1.948066e+05  4.803323e+00   7.328101e+02
# min    1.230600e+04  1.000000e+00  -1.000000e+00
# 25%    1.428500e+05  6.000000e+00   1.260000e+00
# 50%    3.324040e+05  9.000000e+00   1.215000e+01
# 75%    4.525790e+05  1.400000e+01   4.425000e+01
# max    8.525920e+05  1.800000e+01   2.586000e+04

# %%
df.shape
# Out:
# (11679242, 14)

# %%
df.dtypes
# Out:
# state              object
# CCN                 int64
# Provider_Name      object
# city               object
# Ownership_Type     object
# ESRD_Network        int64
# NPI                object
# Chain              object
# Modality           object
# Alternate_CCNs     object
# Measure            object
# Measure_Score     float64
# year               object
# Measure_ID         object
# dtype: object

# %%
#Comprobación de valores faltantes en el conjunto de datos #En el conjunto de datos
for col in df.columns:
    if df[col].dtype == object:
         print(col,df[col][df[col] == '?'].count())
# Out:
# state 0
# Provider_Name 0
# city 0
# Ownership_Type 0
# NPI 0
# Chain 0
# Modality 0
# Alternate_CCNs 0
# Measure 0
# year 0
# Measure_ID 0

# %%
df
# Out:
#          state     CCN                         Provider_Name        city  \
# 0           AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 1           AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 2           AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 3           AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 4           AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# ...        ...     ...                                   ...         ...
# 11679237    GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679238    GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679239    GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679240    GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679241    GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
#
#          Ownership_Type  ESRD_Network         NPI        Chain  \
# ...

# %%
df.columns
# Out:
# Index(['Estado', 'CCN', 'Nombre_del_Proveedor', 'Ciudad', 'Tipo_de_Propiedad',
#        'Red_ESRD', 'NPI', 'Cadena', 'Modalidad', 'CCN_Alternativos', 'Medida',
#        'Puntaje_de_Medida', 'Año', 'ID_de_Medida'],
#       dtype='object')

# %%
nuevos_nombres = {'state': 'Estado', 'Provider_Name': 'Nombre_del_Proveedor', 'city':'Ciudad', 'Ownership_Type':'Tipo_de_Propiedad',
       'ESRD_Network':'Red_ESRD', 'Chain':'Cadena', 'Modality':'Modalidad', 'Alternate_CCNs':'CCN_Alternativos', 'Measure':'Medida',
       'Measure_Score':'Puntaje_de_Medida', 'year':'Año', 'Measure_ID':'ID_de_Medida'}

# Renombra las columnas
df.rename(columns=nuevos_nombres, inplace=True)

# %%
df
# Out:
#          Estado     CCN                  Nombre_del_Proveedor      Ciudad  \
# 0            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 1            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 2            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 3            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 4            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# ...         ...     ...                                   ...         ...
# 11679237     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679238     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679239     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679240     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679241     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
#
#          Tipo_de_Propiedad  Red_ESRD         NPI       Cadena  \
# ...

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df.Año.value_counts()
# Out:
# Año
# 2019               3316573
# 2021               2799455
# 2022               2569672
# 2020               2568938
# Quarter 1, 2022      93314
# Quarter 2, 2022      92674
# Quarter 3, 2022      92161
# Quarter 4, 2022      91674
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 11679237    False
# 11679238    False
# 11679239    False
# 11679240    False
# 11679241    False
# Length: 11679242, dtype: bool

# %%
df.Año
# Out:
# 0           2022
# 1           2022
# 2           2022
# 3           2022
# 4           2022
#             ...
# 11679237    2022
# 11679238    2022
# 11679239    2022
# 11679240    2022
# 11679241    2022
# Name: Año, Length: 11679242, dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of          Estado     CCN                  Nombre_del_Proveedor      Ciudad  \
# 0            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 1            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 2            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 3            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 4            AL   12306    CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# ...         ...     ...                                   ...         ...
# 11679237     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679238     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679239     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679240     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
# 11679241     GA  852592  KIDNEYSPA EAST ATLANTA DIALYSIS, LLC     ATLANTA
#
# ...

# %%
df.iloc[0:10]
# Out:
#   Estado    CCN                Nombre_del_Proveedor      Ciudad  \
# 0     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 1     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 2     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 3     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 4     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 5     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 6     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 7     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 8     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
# 9     AL  12306  CHILDRENS HOSPITAL OF ALABAMA ESRD  BIRMINGHAM
#
#   Tipo_de_Propiedad  Red_ESRD         NPI       Cadena  \
# 0       Unavailable         8  1720166085  INDEPENDENT
# 1       Unavailable         8  1720166085  INDEPENDENT
# 2       Unavailable         8  1720166085  INDEPENDENT
# ...

# %%
#Reemplazar los valores
df.loc[0:10, 'Año'] = df.loc[0:10, 'Año'].apply(lambda x: '2022' if x == 'Quarter 2, 2022' else x)

# %%
df['Año'] = df['Año'].replace('Quarter 4, 2022', '2022', regex=True)

# %%
df.Año.value_counts()
# Out:
# Año
# 2019    3316573
# 2022    2939495
# 2021    2799455
# 2020    2568938
# Name: count, dtype: int64

# %%
# Reemplazar con el valor anterior
df['Año'] = df['Año'].fillna(method='ffill')
# Out:
# C:\Users\miass\AppData\Local\Temp\ipykernel_11908\3052717879.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Año'] = df['Año'].fillna(method='ffill')

# %%
df.to_csv('Instalacion.csv', index=False)
